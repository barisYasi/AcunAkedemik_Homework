# %% [markdown]
# ## Yapay Zeka İçin Python Ödev Mart 1.Hafta

# %%
import numpy as np
import pandas as pd

df = pd.read_excel(r'C:\Users\BarisYasin\Desktop\AKEDEMİK\Udemyakedemi\ToExcel.xlsx') #Excel Dosyasını  okuma ve datafreme şekline getirme fonsksiyonu
print(df)
# Out:
#     Ürün No                 Ürün Adı  Baris Yasin            Kategori  Satış  \
# 0         1           Akıllı Telefon            1      Mobil Cihazlar     10
# 1         2       Dizüstü Bilgisayar            2       Bilgisayarlar      7
# 2         3                   Tablet            3      Mobil Cihazlar     15
# 3         4              Akıllı Saat            4         Aksesuarlar     23
# 4         5        Kablosuz Kulaklık            5         Aksesuarlar     25
# 5         6             Oyun Konsolu            6      Oyun Cihazları      5
# 6         7      Masaüstü Bilgisayar            7       Bilgisayarlar      3
# 7         8       Akıllı Ev Asistanı            8  Akıllı Ev Ürünleri     12
# 8         9            4K Televizyon            9       Televizyonlar      8
# 9        10       Bluetooth Hoparlör           10         Aksesuarlar     18
# 10       11          E-kitap Okuyucu           11      Mobil Cihazlar     23
# ...

# %%
df.dropna()    #Boş değer olan satırları ortaadan kaldırma işlemine yarıyor.
# Out:
#     Ürün No                 Ürün Adı  Baris Yasin            Kategori  Satış  \
# 0         1           Akıllı Telefon            1      Mobil Cihazlar     10
# 1         2       Dizüstü Bilgisayar            2       Bilgisayarlar      7
# 3         4              Akıllı Saat            4         Aksesuarlar     23
# 4         5        Kablosuz Kulaklık            5         Aksesuarlar     25
# 5         6             Oyun Konsolu            6      Oyun Cihazları      5
# 7         8       Akıllı Ev Asistanı            8  Akıllı Ev Ürünleri     12
# 8         9            4K Televizyon            9       Televizyonlar      8
# 10       11          E-kitap Okuyucu           11      Mobil Cihazlar     23
# 11       12            Oyun Klavyesi           12         Aksesuarlar     30
# 12       13  Sanal Gerçeklik Gözlüğü           13      Oyun Cihazları      4
# 13       14                    Drone           14         Aksesuarlar      6
# ...

# %%
df.isnull() #Boş değerleri bulmamıza yardımcı oluyor
# Out:
#     Ürün No  Ürün Adı  Baris Yasin  Kategori  Satış  Fiyat (TL)  \
# 0     False     False        False     False  False       False
# 1     False     False        False     False  False       False
# 2     False     False        False     False  False        True
# 3     False     False        False     False  False       False
# 4     False     False        False     False  False       False
# 5     False     False        False     False  False       False
# 6     False     False        False     False  False        True
# 7     False     False        False     False  False       False
# 8     False     False        False     False  False       False
# 9     False     False        False     False  False        True
# 10    False     False        False     False  False       False
# 11    False     False        False     False  False       False
# 12    False     False        False     False  False       False
# 13    False     False        False     False  False       False
# ...

# %%
df.fillna(0) #DataFramedeki boş değerlere değer atamamızı sağlıyor
# Out:
#     Ürün No                 Ürün Adı  Baris Yasin            Kategori  Satış  \
# 0         1           Akıllı Telefon            1      Mobil Cihazlar     10
# 1         2       Dizüstü Bilgisayar            2       Bilgisayarlar      7
# 2         3                   Tablet            3      Mobil Cihazlar     15
# 3         4              Akıllı Saat            4         Aksesuarlar     23
# 4         5        Kablosuz Kulaklık            5         Aksesuarlar     25
# 5         6             Oyun Konsolu            6      Oyun Cihazları      5
# 6         7      Masaüstü Bilgisayar            7       Bilgisayarlar      3
# 7         8       Akıllı Ev Asistanı            8  Akıllı Ev Ürünleri     12
# 8         9            4K Televizyon            9       Televizyonlar      8
# 9        10       Bluetooth Hoparlör           10         Aksesuarlar     18
# 10       11          E-kitap Okuyucu           11      Mobil Cihazlar     23
# ...

# %%
df.replace(np.nan,40) #Değiştirmek istediğimiz değerleri hangi değerler ile değiştirmek istiyorsan o işe yardımcı oluyor
# Out:
#     Ürün No                 Ürün Adı  Baris Yasin            Kategori  Satış  \
# 0         1           Akıllı Telefon            1      Mobil Cihazlar     10
# 1         2       Dizüstü Bilgisayar            2       Bilgisayarlar      7
# 2         3                   Tablet            3      Mobil Cihazlar     15
# 3         4              Akıllı Saat            4         Aksesuarlar     23
# 4         5        Kablosuz Kulaklık            5         Aksesuarlar     25
# 5         6             Oyun Konsolu            6      Oyun Cihazları      5
# 6         7      Masaüstü Bilgisayar            7       Bilgisayarlar      3
# 7         8       Akıllı Ev Asistanı            8  Akıllı Ev Ürünleri     12
# 8         9            4K Televizyon            9       Televizyonlar      8
# 9        10       Bluetooth Hoparlör           10         Aksesuarlar     18
# 10       11          E-kitap Okuyucu           11      Mobil Cihazlar     23
# ...

# %%
df.head(8) #Tablonun başından ilk kaç değeri almak istersen ona yardımcı oluyor.
# Out:
#    Ürün No             Ürün Adı  Baris Yasin            Kategori  Satış  \
# 0        1       Akıllı Telefon            1      Mobil Cihazlar     10
# 1        2   Dizüstü Bilgisayar            2       Bilgisayarlar      7
# 2        3               Tablet            3      Mobil Cihazlar     15
# 3        4          Akıllı Saat            4         Aksesuarlar     23
# 4        5    Kablosuz Kulaklık            5         Aksesuarlar     25
# 5        6         Oyun Konsolu            6      Oyun Cihazları      5
# 6        7  Masaüstü Bilgisayar            7       Bilgisayarlar      3
# 7        8   Akıllı Ev Asistanı            8  Akıllı Ev Ürünleri     12
#
#    Fiyat (TL)  Toplam Fiyat (TL)
# 0      5000.0              50000
# 1      8500.0              59500
# 2         NaN              45000
# 3      1500.0              30000
# 4       800.0              20000
# 5      4000.0              20000
# 6         NaN              30000
# 7      2000.0              24000

# %%
df.loc[:,['Ürün Adı','Kategori']] # : ile öncesinin ve sonrasının hiçbir önemi yok sadece tırnak içerisinde istediğim değerleri bana yazdır
# Out:
#                    Ürün Adı            Kategori
# 0            Akıllı Telefon      Mobil Cihazlar
# 1        Dizüstü Bilgisayar       Bilgisayarlar
# 2                    Tablet      Mobil Cihazlar
# 3               Akıllı Saat         Aksesuarlar
# 4         Kablosuz Kulaklık         Aksesuarlar
# 5              Oyun Konsolu      Oyun Cihazları
# 6       Masaüstü Bilgisayar       Bilgisayarlar
# 7        Akıllı Ev Asistanı  Akıllı Ev Ürünleri
# 8             4K Televizyon       Televizyonlar
# 9        Bluetooth Hoparlör         Aksesuarlar
# 10          E-kitap Okuyucu      Mobil Cihazlar
# 11            Oyun Klavyesi         Aksesuarlar
# 12  Sanal Gerçeklik Gözlüğü      Oyun Cihazları
# 13                    Drone         Aksesuarlar
# 14          Akıllı Bileklik         Aksesuarlar
# 15     Kablosuz Şarj Cihazı         Aksesuarlar
# 16         Akıllı Termostat  Akıllı Ev Ürünleri
# 17        Güvenlik Kamerası  Akıllı Ev Ürünleri
# 18            Robot Süpürge  Akıllı Ev Ürünleri
# ...

# %%
df.iloc[: 8,:] #İlk kaç satırı yazdırmak istersen onu giriyorsun
# Out:
#    Ürün No             Ürün Adı  Baris Yasin            Kategori  Satış  \
# 0        1       Akıllı Telefon            1      Mobil Cihazlar     10
# 1        2   Dizüstü Bilgisayar            2       Bilgisayarlar      7
# 2        3               Tablet            3      Mobil Cihazlar     15
# 3        4          Akıllı Saat            4         Aksesuarlar     23
# 4        5    Kablosuz Kulaklık            5         Aksesuarlar     25
# 5        6         Oyun Konsolu            6      Oyun Cihazları      5
# 6        7  Masaüstü Bilgisayar            7       Bilgisayarlar      3
# 7        8   Akıllı Ev Asistanı            8  Akıllı Ev Ürünleri     12
#
#    Fiyat (TL)  Toplam Fiyat (TL)
# 0      5000.0              50000
# 1      8500.0              59500
# 2         NaN              45000
# 3      1500.0              30000
# 4       800.0              20000
# 5      4000.0              20000
# 6         NaN              30000
# 7      2000.0              24000

# %%
grup_bazli_satis = df.groupby('Kategori')['Satış'].sum() #Kategori sutününu getiririp oradan satışları gösteriyor
print(grup_bazli_satis)
# Out:
# Kategori
# Aksesuarlar           151
# Akıllı Ev Ürünleri     59
# Bilgisayarlar          20
# Mobil Cihazlar         48
# Oyun Cihazları          9
# Televizyonlar           8
# Name: Satış, dtype: int64

# %%
print(df) #dataframei yazdırdık
# Out:
#     Ürün No                 Ürün Adı  Baris Yasin            Kategori  Satış  \
# 0         1           Akıllı Telefon            1      Mobil Cihazlar     10
# 1         2       Dizüstü Bilgisayar            2       Bilgisayarlar      7
# 2         3                   Tablet            3      Mobil Cihazlar     15
# 3         4              Akıllı Saat            4         Aksesuarlar     23
# 4         5        Kablosuz Kulaklık            5         Aksesuarlar     25
# 5         6             Oyun Konsolu            6      Oyun Cihazları      5
# 6         7      Masaüstü Bilgisayar            7       Bilgisayarlar      3
# 7         8       Akıllı Ev Asistanı            8  Akıllı Ev Ürünleri     12
# 8         9            4K Televizyon            9       Televizyonlar      8
# 9        10       Bluetooth Hoparlör           10         Aksesuarlar     18
# 10       11          E-kitap Okuyucu           11      Mobil Cihazlar     23
# ...

# %%
df.insert(6,"Dükkan",range(50,70)) #Yeni bir sutün eklememize yarıyor.

# %%
print(df)
# Out:
#     Ürün No                 Ürün Adı  Baris Yasin            Kategori  Satış  \
# 0         1           Akıllı Telefon            1      Mobil Cihazlar     10
# 1         2       Dizüstü Bilgisayar            2       Bilgisayarlar      7
# 2         3                   Tablet            3      Mobil Cihazlar     15
# 3         4              Akıllı Saat            4         Aksesuarlar     23
# 4         5        Kablosuz Kulaklık            5         Aksesuarlar     25
# 5         6             Oyun Konsolu            6      Oyun Cihazları      5
# 6         7      Masaüstü Bilgisayar            7       Bilgisayarlar      3
# 7         8       Akıllı Ev Asistanı            8  Akıllı Ev Ürünleri     12
# 8         9            4K Televizyon            9       Televizyonlar      8
# 9        10       Bluetooth Hoparlör           10         Aksesuarlar     18
# 10       11          E-kitap Okuyucu           11      Mobil Cihazlar     23
# ...
